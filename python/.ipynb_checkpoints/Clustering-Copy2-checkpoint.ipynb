# %%
# import required libs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import urllib.request
from sklearn import preprocessing

# %%
# read original dataset from file
df = pd.read_csv('/home/fede/workspace/DataLab/python/data/payments_w_distance.txt', sep='|', header=0, decimal=",")

# %%
remap = {
    'LUNES': 1,
    'MARTES': 2,
    'MIÉRCOLES': 3,
    'JUEVES': 4, 
    'VIERNES': 5,
    'SÁBADO': 6,
    'DOMINGO': 7
}
df['NUM_DIA_SEMANA'] = df['DIA_SEMANA'].map(remap)

# %%
df.FRANJA_HORARIA = pd.to_numeric(df.FRANJA_HORARIA.str.slice(0,2))
df.IMPORTE = df.IMPORTE.astype(float)
df.LAT_CLIENTE = df.LAT_CLIENTE.astype(float)
df.LON_CLIENTE = df.LON_CLIENTE.astype(float)
df.HUMEDAD = df.HUMEDAD.astype(float)
df.SENSAC_TERMICA = df.SENSAC_TERMICA.astype(float)
df.TEMPERATURA = df.TEMPERATURA.astype(float)
df.DISTANCE = df.DISTANCE.astype(float)

# %%
#df_restauracion = df[df.SECTOR == 'RESTAURACION']

# %%
from sklearn.cross_validation import train_test_split
data_train, data_test = train_test_split(df, test_size=.3, random_state=1234)
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

data_train_num = data_train.select_dtypes(include=numerics)

# %%
del data_train_num['CP_CLIENTE']
del data_train_num['CP_COMERCIO']
del data_train_num['TIMESTAMP']
del data_train_num['LAT_CLIENTE']
del data_train_num['LON_CLIENTE']
del data_train_num['HUMEDAD']
del data_train_num['SENSAC_TERMICA']
del data_train_num['TEMPERATURA']
del data_train_num['NUM_DIA_SEMANA']
del data_train_num['FRANJA_HORARIA']
del data_train_num['NUM_OP']
data_train_num.head()
# Out:
#          IMPORTE  NUM_OP   DISTANCE
# 2984619    16.60       2   2.605903
# 1301869    21.45       1   2.441470
# 828235     63.73       1  34.138472
# 410755     76.37       3   0.000000
# 2965294    93.70       1   5.549250

# %%
data_train_norm = data_train_num.copy()

# %%
#data_train_norm.FRANJA_HORARIA = preprocessing.scale(data_train_norm.FRANJA_HORARIA.astype('float64'))
data_train_norm.IMPORTE = preprocessing.scale(data_train_norm.IMPORTE.astype('float64'))
data_train_norm.DISTANCE = preprocessing.scale(data_train_norm.DISTANCE.astype('float64'))

# %%
from scipy.spatial.distance import cdist
from sklearn.cluster import KMeans
clusters = range(1,16)
meandist = []

for k in clusters:
    model = KMeans(n_clusters=k)
    model.fit(data_train_norm)
    predict = model.predict(data_train_norm)
    meandist.append(sum(np.min(cdist(data_train_norm, model.cluster_centers_, 'euclidean'), axis=1))/data_train.shape[0])

# %%
plt.plot(clusters, meandist)
plt.xlabel('number clusters')
plt.ylabel('distance')
plt.title('Choose k number of clusters')

# %%
plt.show()

# %%
model = KMeans(n_clusters=4)
model.fit(data_train_norm)
predict = model.predict(data_train_norm)

# %%
from sklearn.decomposition import PCA
pca_2 = PCA(2)
pca_plot = pca_2.fit_transform(data_train_norm)
plt.scatter(x=pca_plot[:,0], y=pca_plot[:,1], c=model.labels_)
plt.show()

# %%
from pandas import DataFrame
data_train_norm.reset_index(inplace=True, level=0)
index = list(data_train.index)
labels = list(model.labels_)
newlist = dict(zip(index, labels))
clust = DataFrame.from_dict(newlist, orient='index')

# %%
clust.columns = ['CLUSTER']

# %%
data_train['CLUSTER'] = clust.CLUSTER
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
print(data_train.groupby('CLUSTER').mean())
# Out:
#            CP_CLIENTE   CP_COMERCIO  FRANJA_HORARIA    IMPORTE    NUM_OP  \
# CLUSTER
# 0        46243.451465  46011.613613       14.737500  62.328859  1.527473
# 1        46100.453259  46013.644455       14.330712  51.887508  1.213271
# 2        46373.877461  46012.041885       14.660567  58.827622  1.471437
# 3        46235.563772  46011.701458       14.769913  62.401751  1.567824
#
#          LAT_CLIENTE  LON_CLIENTE     TIMESTAMP   HUMEDAD  SENSAC_TERMICA  \
# CLUSTER
# 0          39.451174    -0.455982  1.452298e+09  0.562815       20.149486
# 1          39.476665    -0.442760  1.452961e+09  0.584604       19.668930
# 2          39.432801    -0.452507  1.452430e+09  0.566588       20.264007
# 3          39.451944    -0.455279  1.452611e+09  0.565277       20.013570
#
#          TEMPERATURA   DISTANCE  NUM_DIA_SEMANA
# CLUSTER
# 0          20.043027  14.510965        3.810327
# 1          19.601429  10.645109        4.013872
# 2          20.155477  15.957603        3.852908
# 3          19.916981  14.427985        3.807999

# %%
data_train[data_train.CLUSTER==1].describe(include='all')
# Out:
#           CP_CLIENTE   CP_COMERCIO        SECTOR         DIA  FRANJA_HORARIA  \
# count   19217.000000  19217.000000         19217       19217    19217.000000
# unique           NaN           NaN             7         617             NaN
# top              NaN           NaN  ALIMENTACION  2016-12-24             NaN
# freq             NaN           NaN         19000          68             NaN
# mean    46016.858719  46015.967477           NaN         NaN       14.843940
# std        24.749872      6.106358           NaN         NaN        3.826679
# min     46005.000000  46001.000000           NaN         NaN        2.000000
# 25%     46009.000000  46009.000000           NaN         NaN       12.000000
# 50%     46017.000000  46017.000000           NaN         NaN       14.000000
# 75%     46021.000000  46021.000000           NaN         NaN       18.000000
# max     46980.000000  46026.000000           NaN         NaN       22.000000
#
#              IMPORTE        NUM_OP CIUDAD_CLIENTE   LAT_CLIENTE   LON_CLIENTE  \
# count   19217.000000  19217.000000          19217  19217.000000  19217.000000
# unique           NaN           NaN             16           NaN           NaN
# top              NaN           NaN       Valencia           NaN           NaN
# freq             NaN           NaN          19185           NaN           NaN
# mean      463.684812     18.319977            NaN     39.470306     -0.381737
# std       216.458919      6.225859            NaN      0.019884      0.020308
# min        42.500000     10.000000            NaN     38.970456     -0.685662
# 25%       318.370000     14.000000            NaN     39.456080     -0.396028
# 50%       414.700000     17.000000            NaN     39.470414     -0.381898
# 75%       553.140000     21.000000            NaN     39.484527     -0.372482
# max      2270.140000     71.000000            NaN     39.711859     -0.304278
#
#          ...                   FECHA     TIMESTAMP       HUMEDAD  \
# count    ...                   19217  1.921700e+04  19217.000000
# unique   ...                    3230           NaN           NaN
# top      ...     2016-12-24 12:00:00           NaN           NaN
# freq     ...                      20           NaN           NaN
# mean     ...                     NaN  1.452936e+09      0.570791
# std      ...                     NaN  1.842396e+07      0.166229
# min      ...                     NaN  1.420189e+09      0.100000
# 25%      ...                     NaN  1.436551e+09      0.450000
# 50%      ...                     NaN  1.453540e+09      0.560000
# 75%      ...                     NaN  1.468339e+09      0.680000
# max      ...                     NaN  1.483204e+09      0.980000
#
#        SENSAC_TERMICA   TEMPERATURA  TIEMPO_DESC  DIA_SEMANA      DISTANCE  \
# count    19217.000000  19217.000000        19217       19217  19217.000000
# unique            NaN           NaN            8           7           NaN
# top               NaN           NaN    Despejado      SÁBADO           NaN
# freq              NaN           NaN        14498        4187           NaN
# mean        19.709431     19.631421          NaN         NaN      0.041262
# std          6.622020      6.322040          NaN         NaN      0.924549
# min         -2.900000     -0.140000          NaN         NaN      0.000000
# 25%         14.440000     14.440000          NaN         NaN      0.000000
# 50%         19.100000     19.100000          NaN         NaN      0.000000
# 75%         24.870000     24.870000          NaN         NaN      0.000000
# max         37.510000     40.830000          NaN         NaN     59.381063
#
#        NUM_DIA_SEMANA  CLUSTER
# count    19217.000000  19217.0
# unique            NaN      NaN
# top               NaN      NaN
# freq              NaN      NaN
# mean         3.662486      1.0
# std          1.783080      0.0
# min          1.000000      1.0
# 25%          2.000000      1.0
# 50%          4.000000      1.0
# 75%          5.000000      1.0
# max          7.000000      1.0
#
# [11 rows x 23 columns]

# %%
data_train[data_train.CLUSTER==1].SECTOR.value_counts().plot(kind='bar')
plt.show()

# %%
data_train[data_train.CLUSTER==1].describe(include='all')
# Out:
#           CP_CLIENTE   CP_COMERCIO        SECTOR         DIA  FRANJA_HORARIA  \
# count   25641.000000  25641.000000         25641       25641    25641.000000
# unique           NaN           NaN             1         607             NaN
# top              NaN           NaN  ALIMENTACION  2015-09-26             NaN
# freq             NaN           NaN         25641          67             NaN
# mean    46019.267813  46015.110370           NaN         NaN       14.842947
# std        42.086695      6.728799           NaN         NaN        3.690569
# min     46001.000000  46001.000000           NaN         NaN        2.000000
# 25%     46009.000000  46009.000000           NaN         NaN       12.000000
# 50%     46017.000000  46015.000000           NaN         NaN       14.000000
# 75%     46021.000000  46021.000000           NaN         NaN       18.000000
# max     46980.000000  46026.000000           NaN         NaN       20.000000
#
#              IMPORTE        NUM_OP CIUDAD_CLIENTE   LAT_CLIENTE   LON_CLIENTE  \
# count   25641.000000  25641.000000          25641  25641.000000  25641.000000
# unique           NaN           NaN             52           NaN           NaN
# top              NaN           NaN       Valencia           NaN           NaN
# freq             NaN           NaN          25301           NaN           NaN
# mean      277.006429     10.963223            NaN     39.470372     -0.376960
# std       100.729426      3.838645            NaN      0.023574      0.027935
# min        67.830000      1.000000            NaN     38.934437     -1.231362
# 25%       200.150000      8.000000            NaN     39.456080     -0.388962
# 50%       261.560000     10.000000            NaN     39.470414     -0.380721
# 75%       341.970000     14.000000            NaN     39.484527     -0.358361
# max       919.000000     23.000000            NaN     39.791854     -0.179937
#
#          ...             LON_COMERCIO                FECHA     TIMESTAMP  \
# count    ...                    25641                25641  2.564100e+04
# unique   ...                       21                 3967           NaN
# top      ...     -0.39602750000000003  2015-12-24 12:00:00           NaN
# freq     ...                     2690                   20           NaN
# mean     ...                      NaN                  NaN  1.451910e+09
# std      ...                      NaN                  NaN  1.824511e+07
# min      ...                      NaN                  NaN  1.420189e+09
# 25%      ...                      NaN                  NaN  1.435918e+09
# 50%      ...                      NaN                  NaN  1.452244e+09
# 75%      ...                      NaN                  NaN  1.467389e+09
# max      ...                      NaN                  NaN  1.483204e+09
#
#              HUMEDAD  SENSAC_TERMICA   TEMPERATURA  TIEMPO_DESC  DIA_SEMANA  \
# count   25641.000000    25641.000000  25641.000000        25641       25641
# unique           NaN             NaN           NaN            8           7
# top              NaN             NaN           NaN    Despejado      SÁBADO
# freq             NaN             NaN           NaN        18087        4585
# mean        0.562204       20.196934     20.083682          NaN         NaN
# std         0.167429        6.888720      6.536316          NaN         NaN
# min         0.100000       -2.900000     -0.140000          NaN         NaN
# 25%         0.440000       14.900000     14.900000          NaN         NaN
# 50%         0.550000       19.740000     19.740000          NaN         NaN
# 75%         0.680000       25.580000     25.580000          NaN         NaN
# max         0.980000       37.510000     40.830000          NaN         NaN
#
#        NUM_DIA_SEMANA  CLUSTER
# count    25641.000000  25641.0
# unique            NaN      NaN
# top               NaN      NaN
# freq              NaN      NaN
# mean         3.535627      1.0
# std          1.725392      0.0
# min          1.000000      1.0
# 25%          2.000000      1.0
# 50%          4.000000      1.0
# 75%          5.000000      1.0
# max          7.000000      1.0
#
# [11 rows x 22 columns]

# %%
data_train[data_train.CLUSTER==2].describe(include='all')
# Out:
#           CP_CLIENTE   CP_COMERCIO        SECTOR         DIA  FRANJA_HORARIA  \
# count    8097.000000   8097.000000          8097        8097     8097.000000
# unique           NaN           NaN             1         600             NaN
# top              NaN           NaN  ALIMENTACION  2016-12-23             NaN
# freq             NaN           NaN          8097          44             NaN
# mean    46020.343090  46016.505249           NaN         NaN       14.364579
# std        35.607113      5.844451           NaN         NaN        3.759109
# min     46001.000000  46001.000000           NaN         NaN        4.000000
# 25%     46014.000000  46014.000000           NaN         NaN       12.000000
# 50%     46017.000000  46017.000000           NaN         NaN       12.000000
# 75%     46022.000000  46022.000000           NaN         NaN       18.000000
# max     46980.000000  46026.000000           NaN         NaN       20.000000
#
#             IMPORTE       NUM_OP CIUDAD_CLIENTE  LAT_CLIENTE  LON_CLIENTE  \
# count   8097.000000  8097.000000           8097  8097.000000  8097.000000
# unique          NaN          NaN             15          NaN          NaN
# top             NaN          NaN       Valencia          NaN          NaN
# freq            NaN          NaN           7912          NaN          NaN
# mean     675.166772    23.108559            NaN    39.470792    -0.384933
# std      331.529739     6.915405            NaN     0.023089     0.022082
# min      307.830000     1.000000            NaN    38.892223    -0.857982
# 25%      499.820000    20.000000            NaN    39.452075    -0.396028
# 50%      590.830000    22.000000            NaN    39.467655    -0.388962
# 75%      735.070000    26.000000            NaN    39.484527    -0.373658
# max     7095.600000    71.000000            NaN    39.562810    -0.325432
#
#          ...            LON_COMERCIO                FECHA     TIMESTAMP  \
# count    ...                    8097                 8097  8.097000e+03
# unique   ...                      19                 2327           NaN
# top      ...    -0.39602750000000003  2015-11-07 12:00:00           NaN
# freq     ...                    2035                   14           NaN
# mean     ...                     NaN                  NaN  1.453957e+09
# std      ...                     NaN                  NaN  1.848670e+07
# min      ...                     NaN                  NaN  1.420196e+09
# 25%      ...                     NaN                  NaN  1.438106e+09
# 50%      ...                     NaN                  NaN  1.454519e+09
# 75%      ...                     NaN                  NaN  1.469290e+09
# max      ...                     NaN                  NaN  1.483204e+09
#
#             HUMEDAD  SENSAC_TERMICA  TEMPERATURA  TIEMPO_DESC  DIA_SEMANA  \
# count   8097.000000     8097.000000  8097.000000         8097        8097
# unique          NaN             NaN          NaN            7           6
# top             NaN             NaN          NaN    Despejado      SÁBADO
# freq            NaN             NaN          NaN         6364        2362
# mean       0.576166       19.364500    19.312263          NaN         NaN
# std        0.166988        6.423162     6.175594          NaN         NaN
# min        0.100000        2.280000     3.560000          NaN         NaN
# 25%        0.450000       14.240000    14.240000          NaN         NaN
# 50%        0.570000       18.720000    18.720000          NaN         NaN
# 75%        0.690000       24.200000    24.200000          NaN         NaN
# max        0.980000       37.350000    40.730000          NaN         NaN
#
#        NUM_DIA_SEMANA CLUSTER
# count     8097.000000  8097.0
# unique            NaN     NaN
# top               NaN     NaN
# freq              NaN     NaN
# mean         3.974188     2.0
# std          1.826653     0.0
# min          1.000000     2.0
# 25%          2.000000     2.0
# 50%          4.000000     2.0
# 75%          6.000000     2.0
# max          6.000000     2.0
#
# [11 rows x 22 columns]
