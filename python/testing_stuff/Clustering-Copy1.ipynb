# %%
# import required libs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import urllib.request
from sklearn import preprocessing

# %%
# read original dataset from file
df = pd.read_csv('/home/fede/workspace/DataLab/python/data/payments_w_city_weather.txt', sep='|', header=0, decimal=",")

# %%
remap = {
    'LUNES': 1,
    'MARTES': 2,
    'MIÉRCOLES': 3,
    'JUEVES': 4, 
    'VIERNES': 5,
    'SÁBADO': 6,
    'DOMINGO': 7
}
df['NUM_DIA_SEMANA'] = df['DIA_SEMANA'].map(remap)

# %%
df.FRANJA_HORARIA = pd.to_numeric(df.FRANJA_HORARIA.str.slice(0,2))
df.IMPORTE = df.IMPORTE.astype(float)
df.LAT_CLIENTE = df.LAT_CLIENTE.astype(float)
df.LON_CLIENTE = df.LON_CLIENTE.astype(float)
df.HUMEDAD = df.HUMEDAD.astype(float)
df.SENSAC_TERMICA = df.SENSAC_TERMICA.astype(float)
df.TEMPERATURA = df.TEMPERATURA.astype(float)

# %%
df.head()
# Out:
#    CP_CLIENTE  CP_COMERCIO        SECTOR         DIA  FRANJA_HORARIA  IMPORTE  \
# 0       46001        46001  RESTAURACION  2015-01-02              16     2.70
# 1       46001        46001  RESTAURACION  2015-01-02              20    20.00
# 2       46001        46001  RESTAURACION  2015-01-03              22    13.50
# 3       46001        46001  RESTAURACION  2015-01-06              22    16.80
# 4       46001        46001  RESTAURACION  2015-01-07              14    16.25
#
#    NUM_OP CIUDAD_CLIENTE  LAT_CLIENTE  LON_CLIENTE      ...        \
# 0       1       Valencia    39.474176    -0.380721      ...
# 1       1       Valencia    39.474176    -0.380721      ...
# 2       1       Valencia    39.474176    -0.380721      ...
# 3       1       Valencia    39.474176    -0.380721      ...
# 4       1       Valencia    39.474176    -0.380721      ...
#
#   LAT_COMERCIO LON_COMERCIO                FECHA   TIMESTAMP  HUMEDAD  \
# 0   39.4741757    -0.380721  2015-01-02 16:00:00  1420210800     0.33
# 1   39.4741757    -0.380721  2015-01-02 20:00:00  1420225200     0.73
# 2   39.4741757    -0.380721  2015-01-03 22:00:00  1420318800     0.59
# 3   39.4741757    -0.380721  2015-01-06 22:00:00  1420578000     0.95
# 4   39.4741757    -0.380721  2015-01-07 14:00:00  1420635600     0.52
#
#    SENSAC_TERMICA  TEMPERATURA  TIEMPO_DESC DIA_SEMANA NUM_DIA_SEMANA
# 0           16.99        16.99      Nublado    VIERNES              5
# 1            6.26         7.08    Despejado    VIERNES              5
# 2            8.27         9.81    Despejado     SÁBADO              6
# 3            7.42         7.42      Nublado     MARTES              2
# 4           15.48        15.48    Despejado  MIÉRCOLES              3
#
# [5 rows x 21 columns]

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

newdf = df.select_dtypes(include=numerics)

# %%
del newdf['CP_CLIENTE']
del newdf['CP_COMERCIO']
del newdf['TIMESTAMP']
del newdf['LAT_CLIENTE']
del newdf['LON_CLIENTE']
del newdf['HUMEDAD']
del newdf['SENSAC_TERMICA']
del newdf['TEMPERATURA']
del newdf['NUM_DIA_SEMANA']
newdf.head()
# Out:
#    FRANJA_HORARIA  IMPORTE  NUM_OP
# 0              16     2.70       1
# 1              20    20.00       1
# 2              22    13.50       1
# 3              22    16.80       1
# 4              14    16.25       1

# %%
dataset_array = newdf.values
print(dataset_array.dtype)
print(dataset_array)
# Out:
# float64
# [[  16.      2.7     1.  ]
#  [  20.     20.      1.  ]
#  [  22.     13.5     1.  ]
#  ...,
#  [  18.     30.4     1.  ]
#  [  20.    124.97    1.  ]
#  [  18.     25.22    1.  ]]

# %%
df_norm = newdf.copy()

# %%
df_norm.FRANJA_HORARIA = preprocessing.scale(df_norm.FRANJA_HORARIA.astype('float64'))
df_norm.IMPORTE = preprocessing.scale(df_norm.IMPORTE.astype('float64'))
df_norm.NUM_OP = preprocessing.scale(df_norm.NUM_OP.astype('float64'))

# %%
df_norm.describe()
# Out:
#        FRANJA_HORARIA       IMPORTE        NUM_OP
# count    3.428537e+06  3.428537e+06  3.428537e+06
# mean     9.981686e-17 -3.891042e-16  5.869142e-18
# std      1.000000e+00  1.000000e+00  1.000000e+00
# min     -3.386910e+00 -5.106078e-01 -2.389458e-01
# 25%     -6.070476e-01 -3.830969e-01 -2.389458e-01
# 50%     -1.437372e-01 -2.503779e-01 -2.389458e-01
# 75%      7.828835e-01  1.011239e-02 -2.389458e-01
# max      1.709504e+00  1.502977e+02  3.739357e+01

# %%
from sklearn.cross_validation import train_test_split
data_train, data_test = train_test_split(df_norm, test_size=.3, random_state=1234)
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from scipy.spatial.distance import cdist
from sklearn.cluster import KMeans
clusters = range(1,12)
meandist = []

for k in clusters:
    model = KMeans(n_clusters=k)
    model.fit(data_train)
    predict = model.predict(data_train)
    meandist.append(sum(np.min(cdist(data_train, model.cluster_centers_, 'euclidean'), axis=1))/data_train.shape[0])

# %%
from sklearn.cluster import KMeans
KMeans?

# %%
plt.plot(clusters, meandist)
plt.xlabel('number clusters')
plt.ylabel('distance')
plt.title('select k')

# %%
plt.show()

# %%
model = KMeans(n_clusters=3)
model.fit(data_train)
predict = model.predict(data_train)

# %%
from sklearn.decomposition import PCA
pca_2 = PCA(2)
pca_plot = pca_2.fit_transform(data_train)
plt.scatter(x=pca_plot[:,0], y=pca_plot[:,1], c=model.labels_)
plt.show()

# %%
from pandas import DataFrame
data_train.reset_index(inplace=True, level=0)
index = list(data_train.index)
labels = list(model.labels_)
newlist = dict(zip(index, labels))
clust = DataFrame.from_dict(newlist, orient='index')

# %%
clust.columns = ['CLUSTER']

# %%
data_train['CLUSTER'] = clust.CLUSTER
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
print(data_train.groupby('CLUSTER').mean())
# Out:
#               level_0         index  FRANJA_HORARIA   IMPORTE    NUM_OP
# CLUSTER
# 0        1.200221e+06  1.688068e+06       -0.808969 -0.084430 -0.091262
# 1        1.200450e+06  2.079848e+06        0.014248  4.683079  5.838358
# 2        1.199731e+06  1.728574e+06        0.836718 -0.060134 -0.089632

# %%
# Out:
# array([1, 1, 1, ..., 1, 1, 0], dtype=int32)

# %%
data_train[data_train.CLUSTER==0].describe(include='all')
# Out:
#               index  FRANJA_HORARIA       IMPORTE        NUM_OP    CLUSTER
# count  1.200778e+06    1.200778e+06  1.200778e+06  1.200778e+06  1200778.0
# mean   1.688068e+06   -8.089690e-01 -8.442969e-02 -9.126226e-02        0.0
# std    9.938163e+05    6.845566e-01  5.839953e-01  4.227394e-01        0.0
# min    4.000000e+00   -3.386910e+00 -5.106078e-01 -2.389458e-01        0.0
# 25%    8.224245e+05   -1.070358e+00 -3.915166e-01 -2.389458e-01        0.0
# 50%    1.686402e+06   -6.070476e-01 -2.631377e-01 -2.389458e-01        0.0
# 75%    2.554931e+06   -1.437372e-01 -2.374007e-02 -2.389458e-01        0.0
# max    3.428515e+06   -1.437372e-01  6.650402e+00  5.137127e+00        0.0

# %%
df[df.CLUSTER==1].describe(include='all')
# Out:
#           CP_CLIENTE   CP_COMERCIO               SECTOR         DIA  \
# count   1.898358e+06  1.898358e+06              1898358     1898358
# unique           NaN           NaN                   11         419
# top              NaN           NaN  MODA Y COMPLEMENTOS  2016-12-23
# freq             NaN           NaN               361372        8595
# mean    4.624448e+04  4.601230e+04                  NaN         NaN
# std     3.073512e+02  7.298042e+00                  NaN         NaN
# min     4.600100e+04  4.600100e+04                  NaN         NaN
# 25%     4.601700e+04  4.600600e+04                  NaN         NaN
# 50%     4.611900e+04  4.601300e+04                  NaN         NaN
# 75%     4.638000e+04  4.601900e+04                  NaN         NaN
# max     4.698900e+04  4.602600e+04                  NaN         NaN
#
#         FRANJA_HORARIA       IMPORTE        NUM_OP CIUDAD_CLIENTE  \
# count     1.898358e+06  1.898358e+06  1.898358e+06        1898358
# unique             NaN           NaN           NaN            224
# top                NaN           NaN           NaN       Valencia
# freq               NaN           NaN           NaN         871783
# mean      1.455624e+01  5.070807e+01  1.281945e+00            NaN
# std       4.555945e+00  6.646304e+01  7.774646e-01            NaN
# min       0.000000e+00  1.000000e-02  1.000000e+00            NaN
# 25%       1.200000e+01  1.499000e+01  1.000000e+00            NaN
# 50%       1.400000e+01  3.000000e+01  1.000000e+00            NaN
# 75%       1.800000e+01  5.927000e+01  1.000000e+00            NaN
# max       2.200000e+01  7.875000e+02  1.000000e+01            NaN
#
#          LAT_CLIENTE   LON_CLIENTE    ...     LON_COMERCIO  \
# count   1.898358e+06  1.898358e+06    ...          1898358
# unique           NaN           NaN    ...               21
# top              NaN           NaN    ...        -0.380721
# freq             NaN           NaN    ...           244446
# mean    3.945307e+01 -4.523589e-01    ...              NaN
# std     1.476211e-01  1.756362e-01    ...              NaN
# min     3.875612e+01 -1.462804e+00    ...              NaN
# 25%     3.943923e+01 -4.714694e-01    ...              NaN
# 50%     3.947041e+01 -3.960275e-01    ...              NaN
# 75%     3.950432e+01 -3.630670e-01    ...              NaN
# max     4.012778e+01 -1.027180e-01    ...              NaN
#
#                       FECHA     TIMESTAMP       HUMEDAD  SENSAC_TERMICA  \
# count               1898358  1.898358e+06  1.898358e+06    1.898358e+06
# unique                 5023           NaN           NaN             NaN
# top     2016-12-23 18:00:00           NaN           NaN             NaN
# freq                   1557           NaN           NaN             NaN
# mean                    NaN  1.452538e+09  5.692421e-01    1.989251e+01
# std                     NaN  1.848920e+07  1.744046e-01    6.843876e+00
# min                     NaN  1.420067e+09  1.000000e-01   -3.310000e+00
# 25%                     NaN  1.436450e+09  4.400000e-01    1.471000e+01
# 50%                     NaN  1.452877e+09  5.600000e-01    1.944000e+01
# 75%                     NaN  1.468159e+09  6.900000e-01    2.499000e+01
# max                     NaN  1.483218e+09  9.900000e-01    3.751000e+01
#
#          TEMPERATURA  TIEMPO_DESC  DIA_SEMANA NUM_DIA_SEMANA    CLUSTER
# count   1.898358e+06      1898358     1898358   1.898358e+06  1898358.0
# unique           NaN            7           4            NaN        NaN
# top              NaN    Despejado      SÁBADO            NaN        NaN
# freq             NaN      1360018      564862            NaN        NaN
# mean    1.981236e+01          NaN         NaN   5.322502e+00        1.0
# std     6.535845e+00          NaN         NaN   1.027063e+00        0.0
# min    -1.060000e+00          NaN         NaN   4.000000e+00        1.0
# 25%     1.471000e+01          NaN         NaN   4.000000e+00        1.0
# 50%     1.944000e+01          NaN         NaN   5.000000e+00        1.0
# 75%     2.499000e+01          NaN         NaN   6.000000e+00        1.0
# max     4.083000e+01          NaN         NaN   7.000000e+00        1.0
#
# [11 rows x 22 columns]

# %%
df[df.CLUSTER==2].describe(include='all')
# Out:
#           CP_CLIENTE   CP_COMERCIO        SECTOR         DIA  FRANJA_HORARIA  \
# count   52638.000000  52638.000000         52638       52638    52638.000000
# unique           NaN           NaN            11         725             NaN
# top              NaN           NaN  ALIMENTACION  2016-01-05             NaN
# freq             NaN           NaN         37987         176             NaN
# mean    46078.443102  46014.753942           NaN         NaN       14.671910
# std       190.644038      6.769316           NaN         NaN        3.825347
# min     46001.000000  46001.000000           NaN         NaN        0.000000
# 25%     46011.000000  46009.000000           NaN         NaN       12.000000
# 50%     46018.000000  46015.000000           NaN         NaN       14.000000
# 75%     46025.000000  46020.000000           NaN         NaN       18.000000
# max     46989.000000  46026.000000           NaN         NaN       22.000000
#
#              IMPORTE        NUM_OP CIUDAD_CLIENTE   LAT_CLIENTE   LON_CLIENTE  \
# count   52638.000000  52638.000000          52638  52638.000000  52638.000000
# unique           NaN           NaN            188           NaN           NaN
# top              NaN           NaN       Valencia           NaN           NaN
# freq             NaN           NaN          44956           NaN           NaN
# mean      596.292079     12.248756            NaN     39.465636     -0.399161
# std       524.503437      8.217072            NaN      0.076557      0.094616
# min        11.000000      1.000000            NaN     38.756121     -1.462804
# 25%       286.530000      7.000000            NaN     39.456080     -0.396028
# 50%       424.735000     12.000000            NaN     39.470414     -0.381898
# 75%       765.892500     17.000000            NaN     39.484527     -0.372482
# max     17374.000000     71.000000            NaN     40.100012     -0.102718
#
#          ...             LON_COMERCIO                FECHA     TIMESTAMP  \
# count    ...                    52638                52638  5.263800e+04
# unique   ...                       21                 4700           NaN
# top      ...     -0.39602750000000003  2016-12-24 12:00:00           NaN
# freq     ...                     7038                   54           NaN
# mean     ...                      NaN                  NaN  1.452556e+09
# std      ...                      NaN                  NaN  1.833969e+07
# min      ...                      NaN                  NaN  1.420160e+09
# 25%      ...                      NaN                  NaN  1.436443e+09
# 50%      ...                      NaN                  NaN  1.452625e+09
# 75%      ...                      NaN                  NaN  1.468051e+09
# max      ...                      NaN                  NaN  1.483204e+09
#
#              HUMEDAD  SENSAC_TERMICA   TEMPERATURA  TIEMPO_DESC  DIA_SEMANA  \
# count   52638.000000    52638.000000  52638.000000        52638       52638
# unique           NaN             NaN           NaN            9           7
# top              NaN             NaN           NaN    Despejado      SÁBADO
# freq             NaN             NaN           NaN        39127        9913
# mean        0.568539       19.990849     19.891073          NaN         NaN
# std         0.167134        6.820990      6.491819          NaN         NaN
# min         0.100000       -2.900000     -0.140000          NaN         NaN
# 25%         0.450000       14.660000     14.660000          NaN         NaN
# 50%         0.560000       19.410000     19.410000          NaN         NaN
# 75%         0.680000       25.270000     25.270000          NaN         NaN
# max         0.980000       37.510000     40.830000          NaN         NaN
#
#        NUM_DIA_SEMANA  CLUSTER
# count    52638.000000  52638.0
# unique            NaN      NaN
# top               NaN      NaN
# freq              NaN      NaN
# mean         3.653824      2.0
# std          1.751189      0.0
# min          1.000000      2.0
# 25%          2.000000      2.0
# 50%          4.000000      2.0
# 75%          5.000000      2.0
# max          7.000000      2.0
#
# [11 rows x 22 columns]
